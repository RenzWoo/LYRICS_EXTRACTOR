# %%
import pandas as pd
from pathlib import Path

folder = Path(r'C:\Users\User\Documents\Lyrics')
records = []

for idx, file in enumerate(folder.glob('*.txt')):
    records.append({'id':idx, 'song':file.name,'lyrics':file.read_text(encoding='utf-8')})

# %%
pd.DataFrame(records)
# Out:
#       id                         song  \
# 0      0              ADLAW-ADLAW.txt
# 1      1              ALIVE AGAIN.txt
# 2      2                    ALIVE.txt
# 3      3           ALWAYS ON TIME.txt
# 4      4     ANG ATONG DIOS MAAYO.txt
# ..   ...                          ...
# 120  120  YOU ARE NEAR - HILLSONG.txt
# 121  121                  YOU ARE.txt
# 122  122    YOU DESERVE THE GLORY.txt
# 123  123     YOUR GRACE IS ENOUGH.txt
# 124  124     YOURS IS THE KINGDOM.txt
#
#                                                 lyrics
# 0    Verse\nADLAW-ADLAW'NG MALIPAYON\nADLAW-ADLAW N...
# 1    Verse 1\nWHEN I THINK ABOUT YOUR GOODNESS\n\nM...
# 2    Verse 1\nI WAS LOST WITH A BROKEN HEART\n\nYOU...
# 3    Verse 1\nI REMEMBER HOW YOU PROVIDED\n\nHOW YO...
# 4    Verse\nANG ATONG DIOS MAAYO\nIYA KITANG \nGIAT...
# ..                                                 ...
# 120  Verse 1\nIN AWE OF YOU WE WORSHIP\n\nAND STAND...
# 121  Verse 1\nYOU ARE MY LIGHT AND SALVATION\n\nWHO...
# 122  Verse\nYOU DESERVE THE GLORY AND THE HONOR\n\n...
# 123  Verse 1\nGREAT IS YOUR FAITHFULNESS OH GOD\n\n...
# 124  [V - PreC - C - V - PreC - C - PreC - PreC - C...
#
# [125 rows x 3 columns]
